# %%
# Create database
analysis_history = (
 ("Общий_анализ_крови_лейкоциты", 20240315, 9.8),
 ("Мочевина", 20240315, 6.2),
 ("Креатинин", 20240322, 88),
 ("Общий_анализ_крови_лейкоциты", 20240322, 7.3),
 ("Общий_анализ_крови_лейкоциты", 20250426, 7.1))

# %%
# тут я пробовал, решение в следующей ячейке
for k in analysis_history: 
    if k[0] == "Общий_анализ_крови_лейкоциты":
        print (k)
# Out:
# ('Общий_анализ_крови_лейкоциты', 20240315, 9.8)
# ('Общий_анализ_крови_лейкоциты', 20240322, 7.3)
# ('Общий_анализ_крови_лейкоциты', 20250426, 7.1)

# %%
analysis_leukocytes = []
for k in analysis_history: 
    if k[0] == "Общий_анализ_крови_лейкоциты":
       analysis_leukocytes.append(k)
    analysis_leukocytes.sort()
    analysis_leukocytes.reverse()
for leukocytes in analysis_leukocytes:
    leukocytes_str = str(leukocytes[1])  
    print (f"Дата {leukocytes_str[:4]}.{leukocytes_str[4:6]}.{leukocytes_str[6:8]}, Количество лекоцитов {leukocytes[2]}")
print(analysis_leukocytes)
# Out:
# Дата 2025.04.26, Количество лекоцитов 7.1
# Дата 2024.03.22, Количество лекоцитов 7.3
# Дата 2024.03.15, Количество лекоцитов 9.8
# [('Общий_анализ_крови_лейкоциты', 20250426, 7.1), ('Общий_анализ_крови_лейкоциты', 20240322, 7.3), ('Общий_анализ_крови_лейкоциты', 20240315, 9.8)]

# %%
# это бред, это не смотрите, пожалуйста 
year_list =[0]
month_list =[0]
day_list = [0]
for k in analysis_history: 
    if k[0] == "Общий_анализ_крови_лейкоциты":
        string_type_k = str(k[1])
        year = string_type_k[:4]
        month = string_type_k[4:6]
        day = string_type_k[6:8]
        year_list.append(year)
        month_list.append(month)
        day_list.append(day)
print (year_list, month_list, day_list)
# Out:
# [0, '2024', '2024', '2025'] [0, '03', '03', '04'] [0, '15', '22', '26']
