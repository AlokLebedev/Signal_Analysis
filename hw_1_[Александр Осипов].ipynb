# %%
age1 = int (input('возраст'))
weight1 = int (input('вес (кг)'))
high1 = float (input('рост (м)'))
print (age1, weight1, high1)
# Out:
# 50 70 1.8

# %%
age2 = int (input('возраст'))
weight2 = int (input('вес (кг)'))
high2 = float (input('рост (м)'))
print (age2, weight2, high2)
# попробовал сделать не просто через перменную, а с вводом)
# Out:
# 45 60 1.9

# %%
weight_difference = weight1 / weight2
print (weight_difference)
# Out:
# 1.1666666666666667

# %%
high_difference = high1 / high2
print (high_difference)
# Out:
# 0.9473684210526316

# %%
mass_index1 = weight1 / (high1**2)
mass_index2 = weight2 / (high2**2)

# %%
heart_strokes1 = 80*60*24*365*age1
heart_strokes2 = 80*60*24*365*age2

# %%
print ('результаты пациента 1', mass_index1, heart_strokes1)
print ('результаты пациента 2', mass_index2, heart_strokes2)
# Out:
# результаты пациента 1 21.604938271604937 2102400000
# результаты пациента 2 16.62049861495845 1892160000

# %%
filename = input('название файла')
parts = filename.split('_')
patient_Id = parts[0]
channel_number = parts[1]
fequence = parts[2]
amplitude = parts[3]
noise = parts[4]
print(patient_Id, channel_number, fequence, amplitude, noise )

# Отлично!
# Только нужно получить сами цифры, а не просто блоки 
# То есть, например, вместо ID456 нужно получить 456, а вместо CH12 - 12 и т.д.
# Out:
# ID456 CH12 F40.0 A0.003 B0.001
